# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
density = np.load('D:\TUD\TU_Dresden\WiSe2021\Thesis\phase_space\Phase_Space_Interpolation/boolean_density\Calculated_Density\Calculated_density_2000.npy')

# %%
mask_y = (density[:,0] == 65)
output = density[mask_y, :]
mask_yy = (output[:,2] == 5)
output = output[mask_yy, :]

# %%
plt.plot(output[:,1], output[:,3])
plt.xlabel('Y - axis')
plt.ylabel('density value')
plt.title('density plot')
plt.show()
